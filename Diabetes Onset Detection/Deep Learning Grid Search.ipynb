# %% [markdown]
# ## Deep Learning Grid Search
#
#  In this project, we will learn how to use the scikit-learn grid search capability.
#
#  We are going to learn the following topics:
#
#  1.  How to use Keras models in scikit-learn.
#  2.  How to use grid search in scikit-learn.
#  3.  How to tune batch size and training epochs.
#  4.  How to tune learning rate
#  5.  How to tune network weight initialization.
#  6.  How to tune activation functions.
#  7.  How to tune dropout regularization.
#  8.  How to tune the number of neurons in the hidden layer.

# %%
import sys
import pandas
import numpy
import sklearn
import keras

print('Python: {}'.format(sys.version))
print('Pandas: {}'.format(pandas.__version__))
print('Numpy: {}'.format(numpy.__version__))
print('Sklearn: {}'.format(sklearn.__version__))
print('Keras: {}'.format(keras.__version__))
# Out:
# Python: 3.7.10 (default, Feb 26 2021, 13:06:18) [MSC v.1916 64 bit (AMD64)]
# Pandas: 1.2.4
# Numpy: 1.20.2
# Sklearn: 0.24.2
# Keras: 2.5.0

# %%
import pandas as pd
import numpy as np

# import the uci pima indians diabetes dataset

names = ['n_pregnant', 'glucose_concentration', 'blood_pressuer (mm Hg)', 'skin_thickness (mm)', 'serum_insulin (mu U/ml)',
        'BMI', 'pedigree_function', 'age', 'class']
df = pd.read_csv("diabetes.csv")

#Change the columns name
df.columns = names

# %%
df.describe()
# Out:
#        n_pregnant  glucose_concentration  blood_pressuer (mm Hg)  \
# count  768.000000             768.000000              768.000000
# mean     3.845052             120.894531               69.105469
# std      3.369578              31.972618               19.355807
# min      0.000000               0.000000                0.000000
# 25%      1.000000              99.000000               62.000000
# 50%      3.000000             117.000000               72.000000
# 75%      6.000000             140.250000               80.000000
# max     17.000000             199.000000              122.000000
#
#        skin_thickness (mm)  serum_insulin (mu U/ml)         BMI  \
# count           768.000000               768.000000  768.000000
# mean             20.536458                79.799479   31.992578
# std              15.952218               115.244002    7.884160
# min               0.000000                 0.000000    0.000000
# 25%               0.000000                 0.000000   27.300000
# 50%              23.000000                30.500000   32.000000
# 75%              32.000000               127.250000   36.600000
# max              99.000000               846.000000   67.100000
#
#        pedigree_function         age       class
# count         768.000000  768.000000  768.000000
# mean            0.471876   33.240885    0.348958
# std             0.331329   11.760232    0.476951
# min             0.078000   21.000000    0.000000
# 25%             0.243750   24.000000    0.000000
# 50%             0.372500   29.000000    0.000000
# 75%             0.626250   41.000000    1.000000
# max             2.420000   81.000000    1.000000

# %%
df[df['glucose_concentration'] == 0]
# Out:
#      n_pregnant  glucose_concentration  blood_pressuer (mm Hg)  \
# 75            1                      0                      48
# 182           1                      0                      74
# 342           1                      0                      68
# 349           5                      0                      80
# 502           6                      0                      68
#
#      skin_thickness (mm)  serum_insulin (mu U/ml)   BMI  pedigree_function  \
# 75                    20                        0  24.7              0.140
# 182                   20                       23  27.7              0.299
# 342                   35                        0  32.0              0.389
# 349                   32                        0  41.0              0.346
# 502                   41                        0  39.0              0.727
#
#      age  class
# 75    22      0
# 182   21      0
# 342   22      0
# 349   37      1
# 502   41      1

# %%
# Preprocess the data, mark zero values as NaN and drop

columns = ['glucose_concentration', 'blood_pressuer (mm Hg)', 'skin_thickness (mm)', 'serum_insulin (mu U/ml)', 'BMI']

for col in columns:
    df[col].replace(0, np.NaN, inplace=True)

# %%
df.describe()
# Out:
#        n_pregnant  glucose_concentration  blood_pressuer (mm Hg)  \
# count  768.000000             763.000000              733.000000
# mean     3.845052             121.686763               72.405184
# std      3.369578              30.535641               12.382158
# min      0.000000              44.000000               24.000000
# 25%      1.000000              99.000000               64.000000
# 50%      3.000000             117.000000               72.000000
# 75%      6.000000             141.000000               80.000000
# max     17.000000             199.000000              122.000000
#
#        skin_thickness (mm)  serum_insulin (mu U/ml)         BMI  \
# count           541.000000               394.000000  757.000000
# mean             29.153420               155.548223   32.457464
# std              10.476982               118.775855    6.924988
# min               7.000000                14.000000   18.200000
# 25%              22.000000                76.250000   27.500000
# 50%              29.000000               125.000000   32.300000
# 75%              36.000000               190.000000   36.600000
# max              99.000000               846.000000   67.100000
#
#        pedigree_function         age       class
# count         768.000000  768.000000  768.000000
# mean            0.471876   33.240885    0.348958
# std             0.331329   11.760232    0.476951
# min             0.078000   21.000000    0.000000
# 25%             0.243750   24.000000    0.000000
# 50%             0.372500   29.000000    0.000000
# 75%             0.626250   41.000000    1.000000
# max             2.420000   81.000000    1.000000

# %%
# Drop rows with missing values
df.dropna(inplace=True)

# summarize the number of rows and columns in df
df.describe()
# Out:
#        n_pregnant  glucose_concentration  blood_pressuer (mm Hg)  \
# count  392.000000             392.000000              392.000000
# mean     3.301020             122.627551               70.663265
# std      3.211424              30.860781               12.496092
# min      0.000000              56.000000               24.000000
# 25%      1.000000              99.000000               62.000000
# 50%      2.000000             119.000000               70.000000
# 75%      5.000000             143.000000               78.000000
# max     17.000000             198.000000              110.000000
#
#        skin_thickness (mm)  serum_insulin (mu U/ml)         BMI  \
# count           392.000000               392.000000  392.000000
# mean             29.145408               156.056122   33.086224
# std              10.516424               118.841690    7.027659
# min               7.000000                14.000000   18.200000
# 25%              21.000000                76.750000   28.400000
# 50%              29.000000               125.500000   33.200000
# 75%              37.000000               190.000000   37.100000
# max              63.000000               846.000000   67.100000
#
#        pedigree_function         age       class
# count         392.000000  392.000000  392.000000
# mean            0.523046   30.864796    0.331633
# std             0.345488   10.200777    0.471401
# min             0.085000   21.000000    0.000000
# 25%             0.269750   23.000000    0.000000
# 50%             0.449500   27.000000    0.000000
# 75%             0.687000   36.000000    1.000000
# max             2.420000   81.000000    1.000000

# %%
# Convert dataframe to numpy array

dataset = df.values
print(dataset.shape)
# Out:
# (392, 9)

# %%
# split into input (X) and an output (Y)

X = dataset[:, 0:8].astype(int)
Y = dataset[:, 8].astype(int)

# %%
print(X.shape)
print(Y.shape)
print(X[:5])
print(Y[:5])
# Out:
# (392, 8)
# (392,)
# [[  1  89  66  23  94  28   0  21]
#  [  0 137  40  35 168  43   2  33]
#  [  3  78  50  32  88  31   0  26]
#  [  2 197  70  45 543  30   0  53]
#  [  1 189  60  23 846  30   0  59]]
# [0 1 1 1 1]

# %%
# Normalize the data using sklearn StandardScaler

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)

# %%
print(scaler)
# Out:
# StandardScaler()

# %%
# Transform and display the training data
X_standardized = scaler.transform(X)

data = pd.DataFrame(X_standardized)

# %%
data.describe()
# Out:
#                   0             1             2             3             4  \
# count  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02
# mean  -4.021726e-17  3.129583e-17 -4.641624e-16  1.042250e-16  6.485742e-17
# std    1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00
# min   -1.029213e+00 -2.161731e+00 -3.739001e+00 -2.108484e+00 -1.196867e+00
# 25%   -7.174265e-01 -7.665958e-01 -6.941640e-01 -7.755315e-01 -6.681786e-01
# 50%   -4.056403e-01 -1.176959e-01 -5.314565e-02 -1.384444e-02 -2.574448e-01
# 75%    5.297185e-01  6.609841e-01  5.878727e-01  7.478426e-01  2.859877e-01
# max    4.271153e+00  2.445459e+00  3.151946e+00  3.223325e+00  5.812990e+00
#
#                   5             6             7
# count  3.920000e+02  3.920000e+02  3.920000e+02
# mean   6.287488e-17 -5.947623e-18  1.028089e-16
# std    1.001278e+00  1.001278e+00  1.001278e+00
# min   -2.081881e+00 -2.748019e-01 -9.682991e-01
# 25%   -6.586210e-01 -2.748019e-01 -7.719850e-01
# 50%    5.300919e-02 -2.748019e-01 -3.793569e-01
# 75%    6.223133e-01 -2.748019e-01  5.040564e-01
# max    4.892094e+00  6.061806e+00  4.921123e+00

# %%
# import necessary sklearn and keras packages

from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier

# %%
# Start defining the model

def create_model():
    # create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(4, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.add(Dropout(.2))
    # compile the model
    
    adam = Adam(learning_rate = 0.01)
    model.compile(optimizer= "adam", loss= 'binary_crossentropy', metrics=[ "accuracy"])
    return model

model = create_model()
print(model.summary())
# Out:
# Model: "sequential_153"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_459 (Dense)            (None, 8)                 72
# _________________________________________________________________
# dense_460 (Dense)            (None, 4)                 36
# _________________________________________________________________
# dense_461 (Dense)            (None, 1)                 5
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1)                 0
# =================================================================
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Do a grid search for the optimal batch size and number of epochs
# import necessary packages
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier

# Define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model():
    # create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(4, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
     # compile the model
    adam = Adam(learning_rate = 0.01)
    model.compile(optimizer= "adam", loss= 'binary_crossentropy', metrics=[ "accuracy"])
    return model

# create the model
model = KerasClassifier(build_fn = create_model, verbose = 1)

# define the grid search parameters
batch_size = [10, 20, 40]
epochs = [10, 50, 100]

# make a dictionary of the grid search parameters
param_grid = dict(batch_size=batch_size, epochs=epochs)

# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=None), verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 32/32 [==============================] - 8s 7ms/step - loss: 0.6859 - accuracy: 0.7077
# Epoch 2/10
# 32/32 [==============================] - 0s 10ms/step - loss: 0.6674 - accuracy: 0.6399
# Epoch 3/10
# 32/32 [==============================] - 0s 9ms/step - loss: 0.6338 - accuracy: 0.6563
# Epoch 4/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.5771 - accuracy: 0.6928
# Epoch 5/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.5347 - accuracy: 0.7271: 0s - loss: 0.5346 - accuracy: 0.72
# Epoch 6/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.5298 - accuracy: 0.7463
# Epoch 7/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4588 - accuracy: 0.8019
# Epoch 8/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4563 - accuracy: 0.7706
# Epoch 9/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4155 - accuracy: 0.8310
# Epoch 10/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4527 - accuracy: 0.7908
# 8/8 [==============================] - 2s 6ms/step - loss: 0.5039 - accuracy: 0.8101
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.810 total time=  14.4s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 32/32 [==============================] - 7s 6ms/step - loss: 0.6886 - accuracy: 0.6551
# Epoch 2/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6641 - accuracy: 0.7249
# Epoch 3/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6314 - accuracy: 0.7157
# Epoch 4/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5936 - accuracy: 0.7652
# Epoch 5/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5439 - accuracy: 0.7799
# Epoch 6/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5040 - accuracy: 0.7901
# Epoch 7/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4645 - accuracy: 0.7777
# Epoch 8/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4645 - accuracy: 0.7713
# Epoch 9/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4211 - accuracy: 0.8328
# Epoch 10/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4128 - accuracy: 0.8427
# 8/8 [==============================] - 2s 5ms/step - loss: 0.6567 - accuracy: 0.5823
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.582 total time=  11.8s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 32/32 [==============================] - 7s 6ms/step - loss: 0.6900 - accuracy: 0.6960
# Epoch 2/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6803 - accuracy: 0.6471
# Epoch 3/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6627 - accuracy: 0.6525: 0s - loss: 0.6642 - accuracy: 0.
# Epoch 4/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6358 - accuracy: 0.6679: 0s - loss: 0.6369 - accuracy: 0.66
# Epoch 5/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6000 - accuracy: 0.7182
# Epoch 6/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5740 - accuracy: 0.7297
# Epoch 7/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5402 - accuracy: 0.7843
# Epoch 8/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4924 - accuracy: 0.7862
# Epoch 9/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4688 - accuracy: 0.7931
# Epoch 10/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4920 - accuracy: 0.7727
# 8/8 [==============================] - 2s 5ms/step - loss: 0.4109 - accuracy: 0.8462
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.846 total time=  11.2s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 32/32 [==============================] - 7s 7ms/step - loss: 0.6937 - accuracy: 0.5031
# Epoch 2/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6884 - accuracy: 0.6605
# Epoch 3/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6861 - accuracy: 0.6371
# Epoch 4/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6813 - accuracy: 0.6683
# Epoch 5/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6800 - accuracy: 0.6330
# Epoch 6/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6717 - accuracy: 0.6855
# Epoch 7/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6666 - accuracy: 0.7221
# Epoch 8/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6572 - accuracy: 0.7506
# Epoch 9/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6390 - accuracy: 0.8144
# Epoch 10/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6269 - accuracy: 0.7985
# 8/8 [==============================] - 2s 4ms/step - loss: 0.6233 - accuracy: 0.8205
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.821 total time=  10.7s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 32/32 [==============================] - 6s 5ms/step - loss: 0.6865 - accuracy: 0.6923
# Epoch 2/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6577 - accuracy: 0.6556
# Epoch 3/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6012 - accuracy: 0.6737
# Epoch 4/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5562 - accuracy: 0.6718
# Epoch 5/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.7117
# Epoch 6/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4990 - accuracy: 0.6724
# Epoch 7/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4730 - accuracy: 0.6637
# Epoch 8/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5445 - accuracy: 0.6504
# Epoch 9/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4956 - accuracy: 0.6571
# Epoch 10/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5015 - accuracy: 0.6827
# 8/8 [==============================] - 1s 4ms/step - loss: 0.4751 - accuracy: 0.6795
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.679 total time=   9.2s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 32/32 [==============================] - 6s 5ms/step - loss: 0.6890 - accuracy: 0.7618
# Epoch 2/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6766 - accuracy: 0.6851
# Epoch 3/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6615 - accuracy: 0.6960
# Epoch 4/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6393 - accuracy: 0.7807
# Epoch 5/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6026 - accuracy: 0.7932
# Epoch 6/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5675 - accuracy: 0.7934
# Epoch 7/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5318 - accuracy: 0.7558
# Epoch 8/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.7835
# Epoch 9/50
# 32/32 [==============================] - 0s 8ms/step - loss: 0.4598 - accuracy: 0.7991
# Epoch 10/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4773 - accuracy: 0.7598
# Epoch 11/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4523 - accuracy: 0.7783
# Epoch 12/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4594 - accuracy: 0.7855
# Epoch 13/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4266 - accuracy: 0.7988
# Epoch 14/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4403 - accuracy: 0.7771
# Epoch 15/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4506 - accuracy: 0.7620
# Epoch 16/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4372 - accuracy: 0.7704
# Epoch 17/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4619 - accuracy: 0.7604
# Epoch 18/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4354 - accuracy: 0.8083
# Epoch 19/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4089 - accuracy: 0.8339
# Epoch 20/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4261 - accuracy: 0.7919
# Epoch 21/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4276 - accuracy: 0.7852
# Epoch 22/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3899 - accuracy: 0.8258
# Epoch 23/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4825 - accuracy: 0.7639
# Epoch 24/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3976 - accuracy: 0.8216
# Epoch 25/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4085 - accuracy: 0.8230
# Epoch 26/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4410 - accuracy: 0.8281
# Epoch 27/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3837 - accuracy: 0.8436
# Epoch 28/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3850 - accuracy: 0.8340
# Epoch 29/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3989 - accuracy: 0.8152
# Epoch 30/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4347 - accuracy: 0.8014
# Epoch 31/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4115 - accuracy: 0.8333
# Epoch 32/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4060 - accuracy: 0.8151
# Epoch 33/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4246 - accuracy: 0.8030
# Epoch 34/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4067 - accuracy: 0.8222
# Epoch 35/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3828 - accuracy: 0.8400
# Epoch 36/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3955 - accuracy: 0.8221
# Epoch 37/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4168 - accuracy: 0.7955
# Epoch 38/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4512 - accuracy: 0.8056
# Epoch 39/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4137 - accuracy: 0.8169
# Epoch 40/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3709 - accuracy: 0.8298
# Epoch 41/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3841 - accuracy: 0.8277
# Epoch 42/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3734 - accuracy: 0.8504
# Epoch 43/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3740 - accuracy: 0.8171
# Epoch 44/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4170 - accuracy: 0.7961
# Epoch 45/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4002 - accuracy: 0.8397
# Epoch 46/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3959 - accuracy: 0.8294
# Epoch 47/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4538 - accuracy: 0.80 - 0s 6ms/step - loss: 0.4378 - accuracy: 0.8041
# Epoch 48/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4003 - accuracy: 0.8449
# Epoch 49/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3990 - accuracy: 0.8345
# Epoch 50/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.77 - 0s 5ms/step - loss: 0.4400 - accuracy: 0.7867
# 8/8 [==============================] - 1s 3ms/step - loss: 0.4811 - accuracy: 0.7722
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.772 total time=  15.7s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 32/32 [==============================] - 5s 3ms/step - loss: 0.6831 - accuracy: 0.6878
# Epoch 2/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6430 - accuracy: 0.6638
# Epoch 3/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.6959
# Epoch 4/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5039 - accuracy: 0.7238
# Epoch 5/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4824 - accuracy: 0.7299
# Epoch 6/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.7805
# Epoch 7/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4746 - accuracy: 0.7708
# Epoch 8/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4076 - accuracy: 0.8531
# Epoch 9/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4058 - accuracy: 0.8326
# Epoch 10/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.7980
# Epoch 11/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3900 - accuracy: 0.8532
# Epoch 12/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3982 - accuracy: 0.8335
# Epoch 13/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4315 - accuracy: 0.8052
# Epoch 14/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3621 - accuracy: 0.8609
# Epoch 15/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4036 - accuracy: 0.8453
# Epoch 16/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8201
# Epoch 17/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3657 - accuracy: 0.8566
# Epoch 18/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3669 - accuracy: 0.8342
# Epoch 19/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3813 - accuracy: 0.8318
# Epoch 20/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3800 - accuracy: 0.8210
# Epoch 21/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3668 - accuracy: 0.8334
# Epoch 22/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3605 - accuracy: 0.8418
# Epoch 23/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3707 - accuracy: 0.8356
# Epoch 24/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3792 - accuracy: 0.8493
# Epoch 25/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3258 - accuracy: 0.8738
# Epoch 26/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3674 - accuracy: 0.8604
# Epoch 27/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3782 - accuracy: 0.8339
# Epoch 28/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3529 - accuracy: 0.8477
# Epoch 29/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3460 - accuracy: 0.8587
# Epoch 30/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3909 - accuracy: 0.8367
# Epoch 31/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3365 - accuracy: 0.8479
# Epoch 32/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3796 - accuracy: 0.8341
# Epoch 33/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3716 - accuracy: 0.8379
# Epoch 34/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3561 - accuracy: 0.8286
# Epoch 35/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3417 - accuracy: 0.8574
# Epoch 36/50
# 32/32 [==============================] - 0s 8ms/step - loss: 0.3529 - accuracy: 0.8589
# Epoch 37/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3699 - accuracy: 0.8462
# Epoch 38/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3468 - accuracy: 0.8537
# Epoch 39/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.82 - 0s 5ms/step - loss: 0.3710 - accuracy: 0.8348
# Epoch 40/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3173 - accuracy: 0.87 - 0s 6ms/step - loss: 0.3294 - accuracy: 0.8709
# Epoch 41/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3767 - accuracy: 0.8315
# Epoch 42/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3843 - accuracy: 0.8371
# Epoch 43/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3964 - accuracy: 0.8246
# Epoch 44/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3175 - accuracy: 0.8813
# Epoch 45/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.8430
# Epoch 46/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.8428
# Epoch 47/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3242 - accuracy: 0.8695
# Epoch 48/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3734 - accuracy: 0.8469
# Epoch 49/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3627 - accuracy: 0.8392
# Epoch 50/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8510
# 8/8 [==============================] - 1s 3ms/step - loss: 0.7843 - accuracy: 0.5949
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.595 total time=  19.2s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 32/32 [==============================] - 5s 6ms/step - loss: 0.6909 - accuracy: 0.5771
# Epoch 2/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6730 - accuracy: 0.6745
# Epoch 3/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6485 - accuracy: 0.6365
# Epoch 4/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5900 - accuracy: 0.7033
# Epoch 5/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5722 - accuracy: 0.6499
# Epoch 6/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5137 - accuracy: 0.6872
# Epoch 7/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5285 - accuracy: 0.6339
# Epoch 8/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4661 - accuracy: 0.7102
# Epoch 9/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5430 - accuracy: 0.6362
# Epoch 10/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5019 - accuracy: 0.6734
# Epoch 11/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4887 - accuracy: 0.6620
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5018 - accuracy: 0.65 - 0s 5ms/step - loss: 0.5012 - accuracy: 0.6540
# Epoch 13/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4425 - accuracy: 0.6938
# Epoch 14/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.6646
# Epoch 15/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4324 - accuracy: 0.8396
# Epoch 16/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4742 - accuracy: 0.7939
# Epoch 17/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5212 - accuracy: 0.7918
# Epoch 18/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4865 - accuracy: 0.8102
# Epoch 19/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4694 - accuracy: 0.7914
# Epoch 20/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4349 - accuracy: 0.7787
# Epoch 21/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4828 - accuracy: 0.7850
# Epoch 22/50
# 32/32 [==============================] - 0s 9ms/step - loss: 0.5065 - accuracy: 0.7964
# Epoch 23/50
# 32/32 [==============================] - 0s 8ms/step - loss: 0.4973 - accuracy: 0.7997
# Epoch 24/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4646 - accuracy: 0.8113
# Epoch 25/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4571 - accuracy: 0.8035
# Epoch 26/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4524 - accuracy: 0.7987
# Epoch 27/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.8403
# Epoch 28/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4860 - accuracy: 0.8017
# Epoch 29/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4289 - accuracy: 0.8380
# Epoch 30/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4875 - accuracy: 0.7796
# Epoch 31/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4371 - accuracy: 0.7947
# Epoch 32/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4484 - accuracy: 0.8113
# Epoch 33/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4894 - accuracy: 0.7813
# Epoch 34/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4568 - accuracy: 0.8313
# Epoch 35/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4585 - accuracy: 0.7957
# Epoch 36/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4828 - accuracy: 0.7749
# Epoch 37/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4537 - accuracy: 0.8427: 0s - loss: 0.4206 - accuracy:
# Epoch 38/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4285 - accuracy: 0.8338
# Epoch 39/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4811 - accuracy: 0.7960
# Epoch 40/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4523 - accuracy: 0.8203
# Epoch 41/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4172 - accuracy: 0.8446
# Epoch 42/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4252 - accuracy: 0.8301
# Epoch 43/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4781 - accuracy: 0.8133
# Epoch 44/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4173 - accuracy: 0.8113
# Epoch 45/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4497 - accuracy: 0.7977
# Epoch 46/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4206 - accuracy: 0.8024
# Epoch 47/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4559 - accuracy: 0.8027
# Epoch 48/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4149 - accuracy: 0.8499
# Epoch 49/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4415 - accuracy: 0.8181
# Epoch 50/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4297 - accuracy: 0.8136
# 8/8 [==============================] - 2s 4ms/step - loss: 0.4177 - accuracy: 0.8333
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.833 total time=  15.8s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 32/32 [==============================] - 6s 4ms/step - loss: 0.6905 - accuracy: 0.6011
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6807 - accuracy: 0.6415
# Epoch 3/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6639 - accuracy: 0.6771
# Epoch 4/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6382 - accuracy: 0.7338
# Epoch 5/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6132 - accuracy: 0.7640
# Epoch 6/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5760 - accuracy: 0.7739
# Epoch 7/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5331 - accuracy: 0.7707
# Epoch 8/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5002 - accuracy: 0.7660
# Epoch 9/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4877 - accuracy: 0.7794
# Epoch 10/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7300
# Epoch 11/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4474 - accuracy: 0.8226
# Epoch 12/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4616 - accuracy: 0.7765
# Epoch 13/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4835 - accuracy: 0.7651
# Epoch 14/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4990 - accuracy: 0.7493
# Epoch 15/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4274 - accuracy: 0.7967
# Epoch 16/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4781 - accuracy: 0.7558
# Epoch 17/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4801 - accuracy: 0.7609
# Epoch 18/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4651 - accuracy: 0.7671
# Epoch 19/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4887 - accuracy: 0.7525
# Epoch 20/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4095 - accuracy: 0.8213
# Epoch 21/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4508 - accuracy: 0.7735
# Epoch 22/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4236 - accuracy: 0.8263
# Epoch 23/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4448 - accuracy: 0.7969
# Epoch 24/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4818 - accuracy: 0.7672
# Epoch 25/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5157 - accuracy: 0.7456
# Epoch 26/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4406 - accuracy: 0.7844
# Epoch 27/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4267 - accuracy: 0.7993
# Epoch 28/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4411 - accuracy: 0.8070
# Epoch 29/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4981 - accuracy: 0.7409
# Epoch 30/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4776 - accuracy: 0.7852
# Epoch 31/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4356 - accuracy: 0.8004
# Epoch 32/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4362 - accuracy: 0.7965
# Epoch 33/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4428 - accuracy: 0.7717
# Epoch 34/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4193 - accuracy: 0.8194
# Epoch 35/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4674 - accuracy: 0.8065
# Epoch 36/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4797 - accuracy: 0.7735
# Epoch 37/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4111 - accuracy: 0.8022
# Epoch 38/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4631 - accuracy: 0.7901
# Epoch 39/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4287 - accuracy: 0.7892
# Epoch 40/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4406 - accuracy: 0.7756
# Epoch 41/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4657 - accuracy: 0.7826
# Epoch 42/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4462 - accuracy: 0.7886
# Epoch 43/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4380 - accuracy: 0.8053
# Epoch 44/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4562 - accuracy: 0.7770
# Epoch 45/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4387 - accuracy: 0.7872
# Epoch 46/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4569 - accuracy: 0.7844
# Epoch 47/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4619 - accuracy: 0.7700
# Epoch 48/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4546 - accuracy: 0.7870
# Epoch 49/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4007 - accuracy: 0.8162
# Epoch 50/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4089 - accuracy: 0.8173
# 8/8 [==============================] - 2s 5ms/step - loss: 0.3747 - accuracy: 0.8590
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.859 total time=  15.2s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 32/32 [==============================] - 6s 6ms/step - loss: 0.6830 - accuracy: 0.6570
# Epoch 2/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6523 - accuracy: 0.6609
# Epoch 3/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5856 - accuracy: 0.7088
# Epoch 4/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5478 - accuracy: 0.6466
# Epoch 5/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.5327 - accuracy: 0.6772
# Epoch 6/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5445 - accuracy: 0.6370
# Epoch 7/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5174 - accuracy: 0.6624
# Epoch 8/50
# 32/32 [==============================] - 0s 10ms/step - loss: 0.5024 - accuracy: 0.6530
# Epoch 9/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4833 - accuracy: 0.6693
# Epoch 10/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4854 - accuracy: 0.6765
# Epoch 11/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4820 - accuracy: 0.7061
# Epoch 12/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4843 - accuracy: 0.8267
# Epoch 13/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4786 - accuracy: 0.7946
# Epoch 14/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4737 - accuracy: 0.8131
# Epoch 15/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4899 - accuracy: 0.7839
# Epoch 16/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4923 - accuracy: 0.7961
# Epoch 17/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4905 - accuracy: 0.8064
# Epoch 18/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4566 - accuracy: 0.8125
# Epoch 19/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4634 - accuracy: 0.8077
# Epoch 20/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4520 - accuracy: 0.8371
# Epoch 21/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4276 - accuracy: 0.8035
# Epoch 22/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4705 - accuracy: 0.7991
# Epoch 23/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4831 - accuracy: 0.7762
# Epoch 24/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4465 - accuracy: 0.8008
# Epoch 25/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4689 - accuracy: 0.7750
# Epoch 26/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4461 - accuracy: 0.7987
# Epoch 27/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4772 - accuracy: 0.8062
# Epoch 28/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4774 - accuracy: 0.7897
# Epoch 29/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4788 - accuracy: 0.7814
# Epoch 30/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4536 - accuracy: 0.8323
# Epoch 31/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4486 - accuracy: 0.8198
# Epoch 32/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4588 - accuracy: 0.7964
# Epoch 33/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4175 - accuracy: 0.8253
# Epoch 34/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.8003
# Epoch 35/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.7990
# Epoch 36/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4619 - accuracy: 0.7738
# Epoch 37/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4427 - accuracy: 0.8141
# Epoch 38/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8236
# Epoch 39/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4550 - accuracy: 0.8050
# Epoch 40/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.7844
# Epoch 41/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4305 - accuracy: 0.8152
# Epoch 42/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4376 - accuracy: 0.8118
# Epoch 43/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4348 - accuracy: 0.8057
# Epoch 44/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4392 - accuracy: 0.8055
# Epoch 45/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4475 - accuracy: 0.7977
# Epoch 46/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4410 - accuracy: 0.7961
# Epoch 47/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4454 - accuracy: 0.8000
# Epoch 48/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4364 - accuracy: 0.8001
# Epoch 49/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4266 - accuracy: 0.8167
# Epoch 50/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5081 - accuracy: 0.7664
# 8/8 [==============================] - 2s 6ms/step - loss: 0.4501 - accuracy: 0.8205
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.821 total time=  16.4s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# Epoch 1/100
# 32/32 [==============================] - 6s 5ms/step - loss: 0.6922 - accuracy: 0.6434
# Epoch 2/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6861 - accuracy: 0.6963
# Epoch 3/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6803 - accuracy: 0.6769
# Epoch 4/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6711 - accuracy: 0.7210
# Epoch 5/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6573 - accuracy: 0.7824
# Epoch 6/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6396 - accuracy: 0.7888
# Epoch 7/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6176 - accuracy: 0.7545
# Epoch 8/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5961 - accuracy: 0.7467
# Epoch 9/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.5490 - accuracy: 0.7566
# Epoch 10/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5218 - accuracy: 0.7785
# Epoch 11/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5122 - accuracy: 0.7848
# Epoch 12/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4706 - accuracy: 0.7739
# Epoch 13/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4898 - accuracy: 0.7661
# Epoch 14/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4866 - accuracy: 0.7402
# Epoch 15/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4373 - accuracy: 0.7724
# Epoch 16/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4262 - accuracy: 0.7943
# Epoch 17/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4547 - accuracy: 0.7651
# Epoch 18/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4793 - accuracy: 0.7679
# Epoch 19/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4447 - accuracy: 0.7572
# Epoch 20/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4267 - accuracy: 0.7875
# Epoch 21/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4293 - accuracy: 0.7950
# Epoch 22/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4576 - accuracy: 0.7811
# Epoch 23/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4229 - accuracy: 0.7923
# Epoch 24/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4871 - accuracy: 0.7271
# Epoch 25/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4141 - accuracy: 0.8111
# Epoch 26/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4340 - accuracy: 0.7936
# Epoch 27/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4247 - accuracy: 0.7875
# Epoch 28/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4406 - accuracy: 0.7977
# Epoch 29/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3991 - accuracy: 0.8121
# Epoch 30/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4550 - accuracy: 0.7720
# Epoch 31/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4107 - accuracy: 0.8261
# Epoch 32/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4088 - accuracy: 0.8272
# Epoch 33/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8231
# Epoch 34/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4422 - accuracy: 0.7803
# Epoch 35/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4092 - accuracy: 0.8166
# Epoch 36/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.7930
# Epoch 37/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4063 - accuracy: 0.8291
# Epoch 38/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4042 - accuracy: 0.8311
# Epoch 39/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8163
# Epoch 40/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3888 - accuracy: 0.8276
# Epoch 41/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4123 - accuracy: 0.8135
# Epoch 42/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3811 - accuracy: 0.8419
# Epoch 43/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4468 - accuracy: 0.8007
# Epoch 44/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4306 - accuracy: 0.7956
# Epoch 45/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 0.8304
# Epoch 46/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4280 - accuracy: 0.7888
# Epoch 47/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3866 - accuracy: 0.8347
# Epoch 48/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4508 - accuracy: 0.7866
# Epoch 49/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3864 - accuracy: 0.8274
# Epoch 50/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3985 - accuracy: 0.8195
# Epoch 51/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4331 - accuracy: 0.8012
# Epoch 52/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4017 - accuracy: 0.8161
# Epoch 53/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4223 - accuracy: 0.7857
# Epoch 54/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 0.8288
# Epoch 55/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4064 - accuracy: 0.8479
# Epoch 56/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3774 - accuracy: 0.8447
# Epoch 57/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4058 - accuracy: 0.8155
# Epoch 58/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3984 - accuracy: 0.8268
# Epoch 59/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4044 - accuracy: 0.7810
# Epoch 60/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3979 - accuracy: 0.7957
# Epoch 61/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3956 - accuracy: 0.8058
# Epoch 62/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4293 - accuracy: 0.7787
# Epoch 63/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3899 - accuracy: 0.8018
# Epoch 64/100
# 32/32 [==============================] - ETA: 0s - loss: 0.4331 - accuracy: 0.79 - 0s 6ms/step - loss: 0.4293 - accuracy: 0.7954
# Epoch 65/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3788 - accuracy: 0.8095
# Epoch 66/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3869 - accuracy: 0.8330
# Epoch 67/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3768 - accuracy: 0.8273
# Epoch 68/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4354 - accuracy: 0.7899
# Epoch 69/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4196 - accuracy: 0.8138
# Epoch 70/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3910 - accuracy: 0.8138
# Epoch 71/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3919 - accuracy: 0.7976
# Epoch 72/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3633 - accuracy: 0.8363
# Epoch 73/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3823 - accuracy: 0.8197: 0s - loss: 0.3664 - accuracy: 0.
# Epoch 74/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3749 - accuracy: 0.8197
# Epoch 75/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3664 - accuracy: 0.8393
# Epoch 76/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3947 - accuracy: 0.8262
# Epoch 77/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3898 - accuracy: 0.8249
# Epoch 78/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4224 - accuracy: 0.8078
# Epoch 79/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3930 - accuracy: 0.8136
# Epoch 80/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3679 - accuracy: 0.8433
# Epoch 81/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8425
# Epoch 82/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3828 - accuracy: 0.8233
# Epoch 83/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4064 - accuracy: 0.8167
# Epoch 84/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3774 - accuracy: 0.8278
# Epoch 85/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3825 - accuracy: 0.8226
# Epoch 86/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3709 - accuracy: 0.8337
# Epoch 87/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4047 - accuracy: 0.8287
# Epoch 88/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4097 - accuracy: 0.8059
# Epoch 89/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3813 - accuracy: 0.8321
# Epoch 90/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4247 - accuracy: 0.8077
# Epoch 91/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3655 - accuracy: 0.8307
# Epoch 92/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4015 - accuracy: 0.8146
# Epoch 93/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.8128
# Epoch 94/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3732 - accuracy: 0.8234
# Epoch 95/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4068 - accuracy: 0.8209
# Epoch 96/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4072 - accuracy: 0.8336
# Epoch 97/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3830 - accuracy: 0.8338
# Epoch 98/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3815 - accuracy: 0.8367
# Epoch 99/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3928 - accuracy: 0.8156
# Epoch 100/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4152 - accuracy: 0.7799
# 8/8 [==============================] - 2s 4ms/step - loss: 0.4884 - accuracy: 0.7468
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.747 total time=  22.8s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# Epoch 1/100
# 32/32 [==============================] - 6s 4ms/step - loss: 0.6913 - accuracy: 0.6409
# Epoch 2/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6821 - accuracy: 0.7070
# Epoch 3/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6709 - accuracy: 0.6923
# Epoch 4/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6610 - accuracy: 0.6450
# Epoch 5/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6245 - accuracy: 0.6825
# Epoch 6/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5839 - accuracy: 0.7223
# Epoch 7/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5524 - accuracy: 0.6714
# Epoch 8/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5135 - accuracy: 0.7005
# Epoch 9/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4826 - accuracy: 0.6852
# Epoch 10/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4468 - accuracy: 0.7690
# Epoch 11/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4702 - accuracy: 0.8072
# Epoch 12/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4681 - accuracy: 0.8236
# Epoch 13/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4082 - accuracy: 0.8151
# Epoch 14/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4022 - accuracy: 0.8197
# Epoch 15/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3786 - accuracy: 0.8438
# Epoch 16/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4105 - accuracy: 0.8236
# Epoch 17/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3355 - accuracy: 0.8568
# Epoch 18/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4126 - accuracy: 0.8104
# Epoch 19/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3916 - accuracy: 0.8343
# Epoch 20/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4210 - accuracy: 0.8084
# Epoch 21/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3984 - accuracy: 0.8312
# Epoch 22/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3687 - accuracy: 0.8412
# Epoch 23/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4455 - accuracy: 0.7812
# Epoch 24/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3863 - accuracy: 0.8160
# Epoch 25/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3834 - accuracy: 0.8243
# Epoch 26/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4167 - accuracy: 0.8161
# Epoch 27/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3730 - accuracy: 0.8445
# Epoch 28/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3532 - accuracy: 0.8487
# Epoch 29/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3972 - accuracy: 0.8227
# Epoch 30/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3853 - accuracy: 0.8548
# Epoch 31/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3898 - accuracy: 0.8454
# Epoch 32/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.8134
# Epoch 33/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3684 - accuracy: 0.8249
# Epoch 34/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3474 - accuracy: 0.8458
# Epoch 35/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3842 - accuracy: 0.8178
# Epoch 36/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4088 - accuracy: 0.8189
# Epoch 37/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3512 - accuracy: 0.8612
# Epoch 38/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3782 - accuracy: 0.8395
# Epoch 39/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3776 - accuracy: 0.8459
# Epoch 40/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3646 - accuracy: 0.8459
# Epoch 41/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3866 - accuracy: 0.8449: 0s - loss: 0.3898 - accuracy: 0.84
# Epoch 42/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3508 - accuracy: 0.8715
# Epoch 43/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4100 - accuracy: 0.8238
# Epoch 44/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3379 - accuracy: 0.8730
# Epoch 45/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3654 - accuracy: 0.8524
# Epoch 46/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3841 - accuracy: 0.8554
# Epoch 47/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3400 - accuracy: 0.8467
# Epoch 48/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3737 - accuracy: 0.8237
# Epoch 49/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4138 - accuracy: 0.8147
# Epoch 50/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3647 - accuracy: 0.8595
# Epoch 51/100
# ...
# 2/2 [==============================] - 1s 16ms/step - loss: 0.3931 - accuracy: 0.8462
# [CV 4/5; 9/9] END ....batch_size=40, epochs=100;, score=0.846 total time=  10.9s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# Epoch 1/100
# 8/8 [==============================] - 5s 7ms/step - loss: 0.6947 - accuracy: 0.4761
# Epoch 2/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6899 - accuracy: 0.6479
# Epoch 3/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6840 - accuracy: 0.7120
# Epoch 4/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6816 - accuracy: 0.6594
# Epoch 5/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6755 - accuracy: 0.6777
# Epoch 6/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6674 - accuracy: 0.7266
# Epoch 7/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6646 - accuracy: 0.7088
# Epoch 8/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6538 - accuracy: 0.7491
# Epoch 9/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6511 - accuracy: 0.7351
# Epoch 10/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6358 - accuracy: 0.7615
# Epoch 11/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6225 - accuracy: 0.7786
# Epoch 12/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6126 - accuracy: 0.7525
# Epoch 13/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5981 - accuracy: 0.7705
# Epoch 14/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5859 - accuracy: 0.7629
# Epoch 15/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5730 - accuracy: 0.7687
# Epoch 16/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5613 - accuracy: 0.7592
# Epoch 17/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5536 - accuracy: 0.7481
# Epoch 18/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5341 - accuracy: 0.7729
# Epoch 19/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5064 - accuracy: 0.7968
# Epoch 20/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5286 - accuracy: 0.7459
# Epoch 21/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4963 - accuracy: 0.7849
# Epoch 22/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4972 - accuracy: 0.7759
# Epoch 23/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4945 - accuracy: 0.7646
# Epoch 24/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4911 - accuracy: 0.7610
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.72 - 0s 5ms/step - loss: 0.4893 - accuracy: 0.7586
# Epoch 26/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4844 - accuracy: 0.7646
# Epoch 27/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4828 - accuracy: 0.7743
# Epoch 28/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4966 - accuracy: 0.7424
# Epoch 29/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4605 - accuracy: 0.7865
# Epoch 30/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4618 - accuracy: 0.7840
# Epoch 31/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4580 - accuracy: 0.7704
# Epoch 32/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4611 - accuracy: 0.7818
# Epoch 33/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4549 - accuracy: 0.7709
# Epoch 34/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4749 - accuracy: 0.7579
# Epoch 35/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4500 - accuracy: 0.7625
# Epoch 36/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4744 - accuracy: 0.7507
# Epoch 37/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4569 - accuracy: 0.7658
# Epoch 38/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4687 - accuracy: 0.7349
# Epoch 39/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4265 - accuracy: 0.7831
# Epoch 40/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4446 - accuracy: 0.7497
# Epoch 41/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4440 - accuracy: 0.7658
# Epoch 42/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4346 - accuracy: 0.7659
# Epoch 43/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4535 - accuracy: 0.7793
# Epoch 44/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4609 - accuracy: 0.7574
# Epoch 45/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4491 - accuracy: 0.7808
# Epoch 46/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4463 - accuracy: 0.7673
# Epoch 47/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4852 - accuracy: 0.7452
# Epoch 48/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4194 - accuracy: 0.7856
# Epoch 49/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4512 - accuracy: 0.7753
# Epoch 50/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4181 - accuracy: 0.7892
# Epoch 51/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4499 - accuracy: 0.7642
# Epoch 52/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4280 - accuracy: 0.7841
# Epoch 53/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4304 - accuracy: 0.7874
# Epoch 54/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4694 - accuracy: 0.7518
# Epoch 55/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4232 - accuracy: 0.7944
# Epoch 56/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4678 - accuracy: 0.7586
# Epoch 57/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4057 - accuracy: 0.8089
# Epoch 58/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4501 - accuracy: 0.7674
# Epoch 59/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4387 - accuracy: 0.7967
# Epoch 60/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4198 - accuracy: 0.7903
# Epoch 61/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4684 - accuracy: 0.7626
# Epoch 62/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4524 - accuracy: 0.7639
# Epoch 63/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4558 - accuracy: 0.7590
# Epoch 64/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4507 - accuracy: 0.7602
# Epoch 65/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4618 - accuracy: 0.7678
# Epoch 66/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4192 - accuracy: 0.7745
# Epoch 67/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4561 - accuracy: 0.7601
# Epoch 68/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4596 - accuracy: 0.7906
# Epoch 69/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3870 - accuracy: 0.8171
# Epoch 70/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4122 - accuracy: 0.7982
# Epoch 71/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4431 - accuracy: 0.7696
# Epoch 72/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4245 - accuracy: 0.7797
# Epoch 73/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4685 - accuracy: 0.7512
# Epoch 74/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4405 - accuracy: 0.7524
# Epoch 75/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4272 - accuracy: 0.7783
# Epoch 76/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4370 - accuracy: 0.7564
# Epoch 77/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4286 - accuracy: 0.7860
# Epoch 78/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4221 - accuracy: 0.7721
# Epoch 79/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4161 - accuracy: 0.7774
# Epoch 80/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4192 - accuracy: 0.7888
# Epoch 81/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4164 - accuracy: 0.7954
# Epoch 82/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3985 - accuracy: 0.8073
# Epoch 83/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4615 - accuracy: 0.7532
# Epoch 84/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4170 - accuracy: 0.7851
# Epoch 85/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4797 - accuracy: 0.7518
# Epoch 86/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4842 - accuracy: 0.7488
# Epoch 87/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4536 - accuracy: 0.7861
# Epoch 88/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4488 - accuracy: 0.7376
# Epoch 89/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4184 - accuracy: 0.7783
# Epoch 90/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4586 - accuracy: 0.7708
# Epoch 91/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4151 - accuracy: 0.8025
# Epoch 92/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4040 - accuracy: 0.7998
# Epoch 93/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4515 - accuracy: 0.7752
# Epoch 94/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4387 - accuracy: 0.7801
# Epoch 95/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4455 - accuracy: 0.7887
# Epoch 96/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4087 - accuracy: 0.8026
# Epoch 97/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4155 - accuracy: 0.8105
# Epoch 98/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4238 - accuracy: 0.8038
# Epoch 99/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4434 - accuracy: 0.7846
# Epoch 100/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4660 - accuracy: 0.7658
# 2/2 [==============================] - 1s 0s/step - loss: 0.4469 - accuracy: 0.8462
# [CV 5/5; 9/9] END ....batch_size=40, epochs=100;, score=0.846 total time=  11.2s
# Epoch 1/50
# 10/10 [==============================] - 5s 8ms/step - loss: 0.6926 - accuracy: 0.5719
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6899 - accuracy: 0.6472
# Epoch 3/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6860 - accuracy: 0.6814
# Epoch 4/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6828 - accuracy: 0.6702
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6792 - accuracy: 0.6572
# Epoch 6/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6732 - accuracy: 0.6696
# Epoch 7/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6652 - accuracy: 0.6789
# Epoch 8/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6581 - accuracy: 0.6695
# Epoch 9/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6544 - accuracy: 0.6378
# Epoch 10/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6434 - accuracy: 0.6399
# Epoch 11/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6292 - accuracy: 0.6552
# Epoch 12/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6073 - accuracy: 0.6798
# Epoch 13/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5848 - accuracy: 0.7178
# Epoch 14/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5703 - accuracy: 0.7415
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5664 - accuracy: 0.7765
# Epoch 16/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5461 - accuracy: 0.7960
# Epoch 17/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5458 - accuracy: 0.7678
# Epoch 18/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5325 - accuracy: 0.7692
# Epoch 19/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5287 - accuracy: 0.7457
# Epoch 20/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5018 - accuracy: 0.7921
# Epoch 21/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5045 - accuracy: 0.7666
# Epoch 22/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4934 - accuracy: 0.7544
# Epoch 23/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4686 - accuracy: 0.7902
# Epoch 24/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4739 - accuracy: 0.7795
# Epoch 25/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4779 - accuracy: 0.7675
# Epoch 26/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4594 - accuracy: 0.7830
# Epoch 27/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4492 - accuracy: 0.7847
# Epoch 28/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4342 - accuracy: 0.7748
# Epoch 29/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4497 - accuracy: 0.7643
# Epoch 30/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4609 - accuracy: 0.7687
# Epoch 31/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4300 - accuracy: 0.7996
# Epoch 32/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4449 - accuracy: 0.7947
# Epoch 33/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4798 - accuracy: 0.7623
# Epoch 34/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.7558
# Epoch 35/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4536 - accuracy: 0.7754
# Epoch 36/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4316 - accuracy: 0.8056
# Epoch 37/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4269 - accuracy: 0.8069
# Epoch 38/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4931 - accuracy: 0.7502
# Epoch 39/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4790 - accuracy: 0.7543
# Epoch 40/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4703 - accuracy: 0.7749
# Epoch 41/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4579 - accuracy: 0.7714
# Epoch 42/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4386 - accuracy: 0.7875
# Epoch 43/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4326 - accuracy: 0.7871
# Epoch 44/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4643 - accuracy: 0.7731
# Epoch 45/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4618 - accuracy: 0.7642
# Epoch 46/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4350 - accuracy: 0.7848
# Epoch 47/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4517 - accuracy: 0.7663
# Epoch 48/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4139 - accuracy: 0.8223
# Epoch 49/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4612 - accuracy: 0.7603
# Epoch 50/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4580 - accuracy: 0.7611
# Best: 0.780947744846344, using {'batch_size': 40, 'epochs': 50}
# 0.7477117896080017 (0.10090512011885515) with: {'batch_size': 10, 'epochs': 10}
# 0.7759818196296692 (0.0948176737576454) with: {'batch_size': 10, 'epochs': 50}
# 0.7682570695877076 (0.07863091767587689) with: {'batch_size': 10, 'epochs': 100}
# 0.7325868248939514 (0.07654322379273693) with: {'batch_size': 20, 'epochs': 10}
# 0.7758844494819641 (0.0849364377331393) with: {'batch_size': 20, 'epochs': 50}
# 0.7682570457458496 (0.08522981471408159) with: {'batch_size': 20, 'epochs': 100}
# 0.7427134037017822 (0.08920618468452092) with: {'batch_size': 40, 'epochs': 10}
# 0.780947744846344 (0.0757894432357593) with: {'batch_size': 40, 'epochs': 50}
# 0.7733203530311584 (0.08268947639968383) with: {'batch_size': 40, 'epochs': 100}

# %%
# import necessary packages
from keras.layers import Dropout

# Define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model(learn_rate, dropout_rate):
    # create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(learning_rate = learn_rate)
    model.compile(optimizer= "adam", loss= 'binary_crossentropy', metrics=[ "accuracy"])
    return model

# create the model
model = KerasClassifier(build_fn = create_model, epochs = 100, batch_size = 20, verbose = 0)

# define the grid search parameters
learn_rate = [0.001, 0.01, 0.1]
dropout_rate = [0.0, 0.1, 0.2]

# make a dictionary of the grid search parameters
param_grid = dict(learn_rate=learn_rate, dropout_rate=dropout_rate)

# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=None), verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 1/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.747 total time=  14.0s
# [CV 2/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 2/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.620 total time=  14.0s
# [CV 3/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 3/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.808 total time=  16.6s
# [CV 4/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 4/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.808 total time=  15.4s
# [CV 5/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 5/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.821 total time=  15.9s
# [CV 1/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 1/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.747 total time=  17.8s
# [CV 2/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 2/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.608 total time=  15.5s
# [CV 3/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 3/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.808 total time=  15.8s
# [CV 4/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 4/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.821 total time=  16.0s
# [CV 5/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 5/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.846 total time=  15.4s
# [CV 1/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 1/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.797 total time=  14.9s
# [CV 2/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 2/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.620 total time=  14.0s
# [CV 3/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 3/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.808 total time=  13.6s
# [CV 4/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 4/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.821 total time=  14.0s
# [CV 5/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 5/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.833 total time=  13.3s
# [CV 1/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 1/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.772 total time=  13.4s
# [CV 2/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 2/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.595 total time=  13.9s
# [CV 3/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 3/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.821 total time=  13.6s
# [CV 4/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 4/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.833 total time=  13.0s
# [CV 5/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 5/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.821 total time=  13.3s
# [CV 1/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 1/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.785 total time=  18.3s
# [CV 2/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 2/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.595 total time=  14.3s
# [CV 3/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 3/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.833 total time=  15.1s
# [CV 4/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 4/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.833 total time=  13.8s
# [CV 5/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 5/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.833 total time=  14.0s
# [CV 1/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 1/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.772 total time=  13.3s
# [CV 2/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 2/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.595 total time=  13.5s
# [CV 3/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 3/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.808 total time=  12.5s
# [CV 4/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 4/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.833 total time=  14.1s
# [CV 5/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 5/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.846 total time=  15.2s
# [CV 1/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 1/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.785 total time=  13.2s
# [CV 2/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 2/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.646 total time=  14.0s
# [CV 3/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 3/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.846 total time=  13.9s
# [CV 4/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 4/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.833 total time=  13.9s
# [CV 5/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 5/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.821 total time=  14.3s
# [CV 1/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 1/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.797 total time=  13.3s
# [CV 2/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 2/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.608 total time=  12.8s
# [CV 3/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 3/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.846 total time=  13.7s
# [CV 4/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 4/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.859 total time=  13.3s
# [CV 5/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 5/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.846 total time=  12.8s
# [CV 1/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 1/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.810 total time=  12.3s
# [CV 2/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 2/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.620 total time=  14.2s
# [CV 3/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 3/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.795 total time=  13.9s
# [CV 4/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 4/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.846 total time=  13.5s
# [CV 5/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 5/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.833 total time=  13.6s
# Best: 0.791269063949585, using {'dropout_rate': 0.2, 'learn_rate': 0.01}
# 0.7605972051620483 (0.07471494700739198) with: {'dropout_rate': 0.0, 'learn_rate': 0.001}
# 0.7657578706741333 (0.08554962974696483) with: {'dropout_rate': 0.0, 'learn_rate': 0.01}
# 0.7758519887924195 (0.07872835058884359) with: {'dropout_rate': 0.0, 'learn_rate': 0.1}
# 0.7682895183563232 (0.0891642885316171) with: {'dropout_rate': 0.1, 'learn_rate': 0.001}
# 0.7759493589401245 (0.09243683279691473) with: {'dropout_rate': 0.1, 'learn_rate': 0.01}
# 0.7708536148071289 (0.09151979383303101) with: {'dropout_rate': 0.1, 'learn_rate': 0.1}
# 0.7860759496688843 (0.07317396021948501) with: {'dropout_rate': 0.2, 'learn_rate': 0.001}
# 0.791269063949585 (0.09421604096588138) with: {'dropout_rate': 0.2, 'learn_rate': 0.01}
# 0.780947744846344 (0.08229717381771148) with: {'dropout_rate': 0.2, 'learn_rate': 0.1}

# %%
# Do a grid search to optimize kernel initialization and activation functions

# Define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model(activation, init):
    # create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer= init, activation= activation))
    model.add(Dense(4, input_dim = 8, kernel_initializer= init, activation= activation))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(learning_rate = 0.001)
    model.compile(optimizer= "adam", loss= 'binary_crossentropy', metrics=[ "accuracy"])
    return model

# create the model
model = KerasClassifier(build_fn = create_model, epochs = 100, batch_size = 20, verbose = 0)

# define the grid search parameters
activation = ['softmax', 'relu', 'tanh', 'linear']
init = ['uniform', 'normal', 'zero']

# make a dictionary of the grid search parameters
param_grid = dict(activation = activation, init = init)

# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=None), verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))

means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation=softmax, init=uniform...........................
# [CV 1/5; 1/12] END activation=softmax, init=uniform;, score=0.797 total time=  16.3s
# [CV 2/5; 1/12] START activation=softmax, init=uniform...........................
# [CV 2/5; 1/12] END activation=softmax, init=uniform;, score=0.595 total time=  13.2s
# [CV 3/5; 1/12] START activation=softmax, init=uniform...........................
# [CV 3/5; 1/12] END activation=softmax, init=uniform;, score=0.808 total time=  13.8s
# [CV 4/5; 1/12] START activation=softmax, init=uniform...........................
# [CV 4/5; 1/12] END activation=softmax, init=uniform;, score=0.821 total time=  15.4s
# [CV 5/5; 1/12] START activation=softmax, init=uniform...........................
# [CV 5/5; 1/12] END activation=softmax, init=uniform;, score=0.833 total time=  14.8s
# [CV 1/5; 2/12] START activation=softmax, init=normal............................
# [CV 1/5; 2/12] END activation=softmax, init=normal;, score=0.785 total time=  16.6s
# [CV 2/5; 2/12] START activation=softmax, init=normal............................
# [CV 2/5; 2/12] END activation=softmax, init=normal;, score=0.595 total time=  14.8s
# [CV 3/5; 2/12] START activation=softmax, init=normal............................
# [CV 3/5; 2/12] END activation=softmax, init=normal;, score=0.795 total time=  14.4s
# [CV 4/5; 2/12] START activation=softmax, init=normal............................
# [CV 4/5; 2/12] END activation=softmax, init=normal;, score=0.833 total time=  13.4s
# [CV 5/5; 2/12] START activation=softmax, init=normal............................
# [CV 5/5; 2/12] END activation=softmax, init=normal;, score=0.821 total time=  14.9s
# [CV 1/5; 3/12] START activation=softmax, init=zero..............................
# [CV 1/5; 3/12] END activation=softmax, init=zero;, score=0.646 total time=  14.1s
# [CV 2/5; 3/12] START activation=softmax, init=zero..............................
# [CV 2/5; 3/12] END activation=softmax, init=zero;, score=0.570 total time=  15.6s
# [CV 3/5; 3/12] START activation=softmax, init=zero..............................
# [CV 3/5; 3/12] END activation=softmax, init=zero;, score=0.705 total time=  14.5s
# [CV 4/5; 3/12] START activation=softmax, init=zero..............................
# [CV 4/5; 3/12] END activation=softmax, init=zero;, score=0.744 total time=  13.0s
# [CV 5/5; 3/12] START activation=softmax, init=zero..............................
# [CV 5/5; 3/12] END activation=softmax, init=zero;, score=0.679 total time=  13.5s
# [CV 1/5; 4/12] START activation=relu, init=uniform..............................
# [CV 1/5; 4/12] END activation=relu, init=uniform;, score=0.797 total time=  12.4s
# [CV 2/5; 4/12] START activation=relu, init=uniform..............................
# [CV 2/5; 4/12] END activation=relu, init=uniform;, score=0.595 total time=  12.9s
# [CV 3/5; 4/12] START activation=relu, init=uniform..............................
# [CV 3/5; 4/12] END activation=relu, init=uniform;, score=0.795 total time=  12.0s
# [CV 4/5; 4/12] START activation=relu, init=uniform..............................
# [CV 4/5; 4/12] END activation=relu, init=uniform;, score=0.795 total time=  11.8s
# [CV 5/5; 4/12] START activation=relu, init=uniform..............................
# [CV 5/5; 4/12] END activation=relu, init=uniform;, score=0.821 total time=  12.8s
# [CV 1/5; 5/12] START activation=relu, init=normal...............................
# [CV 1/5; 5/12] END activation=relu, init=normal;, score=0.797 total time=  12.7s
# [CV 2/5; 5/12] START activation=relu, init=normal...............................
# [CV 2/5; 5/12] END activation=relu, init=normal;, score=0.608 total time=  12.9s
# [CV 3/5; 5/12] START activation=relu, init=normal...............................
# [CV 3/5; 5/12] END activation=relu, init=normal;, score=0.846 total time=  13.8s
# [CV 4/5; 5/12] START activation=relu, init=normal...............................
# [CV 4/5; 5/12] END activation=relu, init=normal;, score=0.846 total time=  12.2s
# [CV 5/5; 5/12] START activation=relu, init=normal...............................
# [CV 5/5; 5/12] END activation=relu, init=normal;, score=0.846 total time=  12.3s
# [CV 1/5; 6/12] START activation=relu, init=zero.................................
# [CV 1/5; 6/12] END ..activation=relu, init=zero;, score=0.646 total time=  12.9s
# [CV 2/5; 6/12] START activation=relu, init=zero.................................
# [CV 2/5; 6/12] END ..activation=relu, init=zero;, score=0.570 total time=  12.7s
# [CV 3/5; 6/12] START activation=relu, init=zero.................................
# [CV 3/5; 6/12] END ..activation=relu, init=zero;, score=0.705 total time=  12.3s
# [CV 4/5; 6/12] START activation=relu, init=zero.................................
# [CV 4/5; 6/12] END ..activation=relu, init=zero;, score=0.744 total time=  12.3s
# [CV 5/5; 6/12] START activation=relu, init=zero.................................
# [CV 5/5; 6/12] END ..activation=relu, init=zero;, score=0.679 total time=  13.0s
# [CV 1/5; 7/12] START activation=tanh, init=uniform..............................
# [CV 1/5; 7/12] END activation=tanh, init=uniform;, score=0.810 total time=  13.2s
# [CV 2/5; 7/12] START activation=tanh, init=uniform..............................
# [CV 2/5; 7/12] END activation=tanh, init=uniform;, score=0.608 total time=  12.7s
# [CV 3/5; 7/12] START activation=tanh, init=uniform..............................
# [CV 3/5; 7/12] END activation=tanh, init=uniform;, score=0.808 total time=  11.9s
# [CV 4/5; 7/12] START activation=tanh, init=uniform..............................
# [CV 4/5; 7/12] END activation=tanh, init=uniform;, score=0.833 total time=  11.9s
# [CV 5/5; 7/12] START activation=tanh, init=uniform..............................
# [CV 5/5; 7/12] END activation=tanh, init=uniform;, score=0.846 total time=  12.4s
# [CV 1/5; 8/12] START activation=tanh, init=normal...............................
# [CV 1/5; 8/12] END activation=tanh, init=normal;, score=0.810 total time=  12.1s
# [CV 2/5; 8/12] START activation=tanh, init=normal...............................
# [CV 2/5; 8/12] END activation=tanh, init=normal;, score=0.608 total time=  12.4s
# [CV 3/5; 8/12] START activation=tanh, init=normal...............................
# [CV 3/5; 8/12] END activation=tanh, init=normal;, score=0.795 total time=  12.0s
# [CV 4/5; 8/12] START activation=tanh, init=normal...............................
# [CV 4/5; 8/12] END activation=tanh, init=normal;, score=0.833 total time=  11.3s
# [CV 5/5; 8/12] START activation=tanh, init=normal...............................
# [CV 5/5; 8/12] END activation=tanh, init=normal;, score=0.846 total time=  12.5s
# [CV 1/5; 9/12] START activation=tanh, init=zero.................................
# [CV 1/5; 9/12] END ..activation=tanh, init=zero;, score=0.646 total time=  13.6s
# [CV 2/5; 9/12] START activation=tanh, init=zero.................................
# [CV 2/5; 9/12] END ..activation=tanh, init=zero;, score=0.570 total time=  12.5s
# [CV 3/5; 9/12] START activation=tanh, init=zero.................................
# [CV 3/5; 9/12] END ..activation=tanh, init=zero;, score=0.705 total time=   9.9s
# [CV 4/5; 9/12] START activation=tanh, init=zero.................................
# [CV 4/5; 9/12] END ..activation=tanh, init=zero;, score=0.744 total time=  12.1s
# [CV 5/5; 9/12] START activation=tanh, init=zero.................................
# [CV 5/5; 9/12] END ..activation=tanh, init=zero;, score=0.679 total time=  14.2s
# [CV 1/5; 10/12] START activation=linear, init=uniform...........................
# [CV 1/5; 10/12] END activation=linear, init=uniform;, score=0.797 total time=  15.2s
# [CV 2/5; 10/12] START activation=linear, init=uniform...........................
# [CV 2/5; 10/12] END activation=linear, init=uniform;, score=0.620 total time=  14.6s
# [CV 3/5; 10/12] START activation=linear, init=uniform...........................
# [CV 3/5; 10/12] END activation=linear, init=uniform;, score=0.833 total time=  15.5s
# [CV 4/5; 10/12] START activation=linear, init=uniform...........................
# [CV 4/5; 10/12] END activation=linear, init=uniform;, score=0.821 total time=  14.9s
# [CV 5/5; 10/12] START activation=linear, init=uniform...........................
# [CV 5/5; 10/12] END activation=linear, init=uniform;, score=0.808 total time=  14.2s
# [CV 1/5; 11/12] START activation=linear, init=normal............................
# [CV 1/5; 11/12] END activation=linear, init=normal;, score=0.810 total time=  14.9s
# [CV 2/5; 11/12] START activation=linear, init=normal............................
# [CV 2/5; 11/12] END activation=linear, init=normal;, score=0.633 total time=  15.5s
# [CV 3/5; 11/12] START activation=linear, init=normal............................
# [CV 3/5; 11/12] END activation=linear, init=normal;, score=0.833 total time=  15.0s
# [CV 4/5; 11/12] START activation=linear, init=normal............................
# [CV 4/5; 11/12] END activation=linear, init=normal;, score=0.821 total time=  15.3s
# [CV 5/5; 11/12] START activation=linear, init=normal............................
# [CV 5/5; 11/12] END activation=linear, init=normal;, score=0.821 total time=  14.9s
# [CV 1/5; 12/12] START activation=linear, init=zero..............................
# [CV 1/5; 12/12] END activation=linear, init=zero;, score=0.646 total time=  15.6s
# [CV 2/5; 12/12] START activation=linear, init=zero..............................
# [CV 2/5; 12/12] END activation=linear, init=zero;, score=0.570 total time=  14.9s
# [CV 3/5; 12/12] START activation=linear, init=zero..............................
# [CV 3/5; 12/12] END activation=linear, init=zero;, score=0.705 total time=  15.4s
# [CV 4/5; 12/12] START activation=linear, init=zero..............................
# [CV 4/5; 12/12] END activation=linear, init=zero;, score=0.744 total time=  14.8s
# [CV 5/5; 12/12] START activation=linear, init=zero..............................
# [CV 5/5; 12/12] END activation=linear, init=zero;, score=0.679 total time=  14.2s
# Best: 0.7887049674987793, using {'activation': 'relu', 'init': 'normal'}
# 0.7707887053489685 (0.08874898667313356) with: {'activation': 'softmax', 'init': 'uniform'}
# 0.7656929612159729 (0.08712634211022303) with: {'activation': 'softmax', 'init': 'normal'}
# 0.6686789989471436 (0.05899773033245815) with: {'activation': 'softmax', 'init': 'zero'}
# 0.7605323076248169 (0.08335734373071611) with: {'activation': 'relu', 'init': 'uniform'}
# 0.7887049674987793 (0.09249732446994784) with: {'activation': 'relu', 'init': 'normal'}
# 0.6686789989471436 (0.05899773033245815) with: {'activation': 'relu', 'init': 'zero'}
# 0.7809801936149597 (0.08787941974436711) with: {'activation': 'tanh', 'init': 'uniform'}
# 0.778416097164154 (0.08724738389943165) with: {'activation': 'tanh', 'init': 'normal'}
# 0.6686789989471436 (0.05899773033245815) with: {'activation': 'tanh', 'init': 'zero'}
# 0.7758519887924195 (0.07872835058884359) with: {'activation': 'linear', 'init': 'uniform'}
# 0.7834793925285339 (0.07564279683053157) with: {'activation': 'linear', 'init': 'normal'}
# 0.6686789989471436 (0.05899773033245815) with: {'activation': 'linear', 'init': 'zero'}

# %%
# Do a grid search to find the optimal number of neurons in each hidden layer

# Define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model(neuron1, neuron2):
    # create model
    model = Sequential()
    model.add(Dense(neuron1, input_dim = 8, kernel_initializer= 'uniform', activation= 'linear'))
    model.add(Dense(neuron2, input_dim = neuron1, kernel_initializer= 'uniform', activation= 'linear'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(learning_rate = 0.001)
    model.compile(optimizer= "adam", loss= 'binary_crossentropy', metrics=[ "accuracy"])
    return model

# create the model
model = KerasClassifier(build_fn = create_model, epochs = 100, batch_size = 20, verbose = 0)

# define the grid search parameters
neuron1 = [4, 8, 16]
neuron2 = [2, 4, 8]

# make a dictionary of the grid search parameters
param_grid = dict(neuron1 = neuron1, neuron2 = neuron2)

# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=None), refit = True, verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.810 total time=  12.9s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.633 total time=  12.2s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.833 total time=  12.5s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.821 total time=  12.6s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.821 total time=  12.3s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.810 total time=  13.5s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.620 total time=  12.2s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.833 total time=  12.1s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.821 total time=  11.9s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.808 total time=  12.0s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.797 total time=  11.9s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.620 total time=  12.1s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.833 total time=  12.0s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.821 total time=  12.0s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.808 total time=  13.0s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.797 total time=  11.7s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.620 total time=  12.3s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.833 total time=  12.4s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.821 total time=  11.5s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.833 total time=  12.2s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.810 total time=  12.0s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.620 total time=  12.7s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.833 total time=  11.3s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.821 total time=  13.7s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.808 total time=  11.5s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.810 total time=  16.9s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.620 total time=  12.1s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.833 total time=  11.5s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.821 total time=  11.8s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.808 total time=  12.2s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.810 total time=  11.3s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.620 total time=  13.5s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.833 total time=  13.4s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.821 total time=  12.2s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.808 total time=  12.9s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.797 total time=  13.8s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.633 total time=  13.0s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.833 total time=  14.1s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.821 total time=  13.4s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.808 total time=  11.3s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.797 total time=  11.4s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.633 total time=  13.4s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.833 total time=  12.8s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.821 total time=  13.3s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.808 total time=  13.1s
# Best: 0.7834793925285339, using {'neuron1': 4, 'neuron2': 2}
# 0.7834793925285339 (0.07564279683053157) with: {'neuron1': 4, 'neuron2': 2}
# 0.7783836364746094 (0.0795816576855425) with: {'neuron1': 4, 'neuron2': 4}
# 0.7758519887924195 (0.07872835058884359) with: {'neuron1': 4, 'neuron2': 8}
# 0.7809801936149597 (0.0814242856340379) with: {'neuron1': 8, 'neuron2': 2}
# 0.7783836364746094 (0.0795816576855425) with: {'neuron1': 8, 'neuron2': 4}
# 0.7783836364746094 (0.0795816576855425) with: {'neuron1': 8, 'neuron2': 8}
# 0.7783836364746094 (0.0795816576855425) with: {'neuron1': 16, 'neuron2': 2}
# 0.7783836364746094 (0.07372887660494651) with: {'neuron1': 16, 'neuron2': 4}
# 0.7783836364746094 (0.07372887660494651) with: {'neuron1': 16, 'neuron2': 8}

# %%
# generate predictions with optimal hyperparameters
y_pred = grid.predict(X_standardized)

# %%
print(y_pred.shape)
# Out:
# (392, 1)

# %%
print(y_pred[:5])
# Out:
# [[0]
#  [1]
#  [0]
#  [1]
#  [1]]

# %%
# Generate a classification report
from sklearn.metrics import classification_report, accuracy_score

print(accuracy_score(Y, y_pred))
print(classification_report(Y, y_pred))
# Out:
# 0.7857142857142857
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.85       262
#            1       0.71      0.59      0.65       130
#
#     accuracy                           0.79       392
#    macro avg       0.76      0.74      0.75       392
# weighted avg       0.78      0.79      0.78       392
